# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\SUDARSHAN\Indian telecommunications market.csv")
df
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10   11/2/2021 11:42:52                                 North
# 11   11/3/2021 15:36:07                                 North
# 12   11/7/2021 11:46:31                                  West
# 13   11/12/2021 9:04:52                                 North
# ...

# %%
print(df)
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 0   10/28/2021 18:56:57                                  West
# 1   10/28/2021 19:14:06                                 North
# 2   10/28/2021 21:30:05                                  West
# 3   10/28/2021 23:06:31                                  East
# 4    10/29/2021 6:35:21                                  West
# 5   10/29/2021 13:43:02                                 North
# 6   10/29/2021 20:00:31                                 North
# 7   10/29/2021 22:53:01                                 North
# 8   10/31/2021 15:46:14                                  West
# 9   10/31/2021 22:00:24                                 North
# 10   11/2/2021 11:42:52                                 North
# 11   11/3/2021 15:36:07                                 North
# 12   11/7/2021 11:46:31                                  West
# 13   11/12/2021 9:04:52                                 North
# ...

# %%
df.shape
# Out:
# (50, 28)

# %%
df.head()
# Out:
#              Timestamp 1.Which region of India are you from?  \
# 0  10/28/2021 18:56:57                                  West
# 1  10/28/2021 19:14:06                                 North
# 2  10/28/2021 21:30:05                                  West
# 3  10/28/2021 23:06:31                                  East
# 4   10/29/2021 6:35:21                                  West
#
#   2.Which type of location do you live in?  \
# 0                                    Urban
# 1                                    Urban
# 2                                    Urban
# 3                                    Urban
# 4                                    Urban
#
#   3.Which tech are you currently using?  \
# 0                                    4G
# 1                                    4G
# 2                                    4G
# 3                                    4G
# 4                                    4G
#
# ...

# %%
df.tail()
# Out:
#               Timestamp 1.Which region of India are you from?  \
# 45   11/23/2021 1:13:47                                  West
# 46  11/23/2021 14:50:27                                 South
# 47  11/23/2021 15:18:27                                 North
# 48  11/23/2021 17:33:13                                  West
# 49  11/23/2021 20:24:58                                  East
#
#    2.Which type of location do you live in?  \
# 45                                 Suburban
# 46                                    Urban
# 47                                    Urban
# 48                                 Suburban
# 49                                    Urban
#
#    3.Which tech are you currently using?  \
# 45                                    4G
# 46                                    4G
# 47                                    4G
# 48                                    4G
# 49                                    3G
#
# ...

# %% [markdown]
# Data Cleaning & Preparation

# %%
#Dropping columns by index position--> Timestamp
df = df.drop(df.columns[0], axis=1)
df.head()
# Out:
#   1.Which region of India are you from?  \
# 0                                  West
# 1                                 North
# 2                                  West
# 3                                  East
# 4                                  West
#
#   2.Which type of location do you live in?  \
# 0                                    Urban
# 1                                    Urban
# 2                                    Urban
# 3                                    Urban
# 4                                    Urban
#
#   3.Which tech are you currently using?  \
# 0                                    4G
# 1                                    4G
# 2                                    4G
# 3                                    4G
# 4                                    4G
#
#   4.Can you send an email with no attachments and just paragraphs of text instantly?  \
# 0                                                Yes
# 1                                                Yes
# ...

# %%
df.columns
# Out:
# Index(['1.Which region of India are you from?',
#        '2.Which type of location do you live in?',
#        '3.Which tech are you currently using?',
#        '4.Can you send an email with no attachments and just paragraphs of text instantly?',
#        '5.Are one-on-one video calls a smooth experience?',
#        '6.Do you experience delays in video conference calls?',
#        '7.How long does it take you to download a song of 4 minutes?',
#        '8.How much data do you use each month?',
#        '9.What do you usually do with your phone? (Multiple choices)',
#        '10.What do you think about the call drop rate? ',
#        '11.Which network are you likely to recommend to a tourist who is in town for a few days?',
#        '12.Which network do you use more often?',
#        '13-VI.Why do you use your current network?',
#        '14-VI.How much are you paying for your mobile bill & WiFi services per month currently?',
# ...

# %%
#Renaming the column names
df.rename(columns={
    '1.Which region of India are you from?':'Region',
    '2.Which type of location do you live in?':'Location',
    '3.Which tech are you currently using?':'Current Using Tech',
    '4.Can you send an email with no attachments and just paragraphs of text instantly?':'Instant Email Test',
    '5.Are one-on-one video calls a smooth experience?':'1v1 Video Call Experience',
    '6.Do you experience delays in video conference calls?':'Delays in Calls',
    '7.How long does it take you to download a song of 4 minutes?':'Download time for song of 4 times',
    '8.How much data do you use each month?':'Data Usage in Month',
    '9.What do you usually do with your phone? (Multiple choices)':'Usual Phone Usage Purpose',
    '10.What do you think about the call drop rate? ':'Call drop Rate',
    '11.Which network are you likely to recommend to a tourist who is in town for a few days?':'Recommendation of network to the tourist',
    '12.Which network do you use more often?':'Preferred Network',
    '13-VI.Why do you use your current network?':'(VI) Reason of Using Current Network',
    '14-VI.How much are you paying for your mobile bill & WiFi services per month currently?':'(VI) Mobile Bill & WiFi Services Monthly Expense',
    '15-VI.If Airtel lowers its price a little, or if Jio provides higher quality services, will you switch?':'Price-Quality Switch(B/W Jio & Airtel)',
    '16-VI.Rate the service quality':'Service Quality Rating (VI)',
    '13-Jio.Why do you use your current network?':'(Jio) Reason of Using Current Network',
    '14-Jio.How much are you paying for your mobile bill & WiFi services per month currently?':'(Jio) Mobile Bill & WiFi Services Monthly Expense',
    '15-Jio.If VI lowers its price for services to the same level as Jio, will you switch to VI?':'Switch to VI?',
    '16-Jio.Rate the service quality':'Service Quality Rating (Jio)',
    '13-Airtel.Why do you use your current network?':'(Airtel) Reason of Using Current Network',
    '14-Airtel.How much are you paying for your mobile bill & WiFi services per month currently?':'(Airtel) Mobile Bill & WiFi Services Monthly Expense',
    '15-Airtel.If VI lowers its price for services to the same level as Airtel, will you switch to VI?':'Switch to VI?',
    '16-Airtel.If VI provides higher quality services with a higher price as compared to Airtel, will you switch to VI?':'Price-Quality Switch(B/W VI & Airtel)',
    '17-Airtel.Rate the service quality':'Service Quality Rating (Airtel)',
    '18.How much support do you think these companies are obtaining from the government?':'Government Support To Network Companies',
    '19.Do you think the telecommunications market in India is tilting towards a monopoly?':'Telecommunications Market in India is Tilting Towards a Monopoly?'
}, inplace=True)
df.head()
# Out:
#   Region Location Current Using Tech Instant Email Test  \
# 0   West    Urban                 4G                Yes
# 1  North    Urban                 4G                Yes
# 2   West    Urban                 4G                 No
# 3   East    Urban                 4G                Yes
# 4   West    Urban                 4G                Yes
#
#   1v1 Video Call Experience Delays in Calls Download time for song of 4 times  \
# 0                       Yes              No                   Less than 1 min
# 1                       Yes             Yes                   Less than 1 min
# 2                       Yes              No                   1 min to 2 mins
# 3                       Yes              No                   1 min to 2 mins
# 4                        No              No                   Less than 1 min
#
#   Data Usage in Month                          Usual Phone Usage Purpose  \
# 0         1GB to 10GB  Social Media and Instant messaging, Online Mee...
# ...

# %%
#Replacing Column values in a Pandas DataFrame

# %%
print(df.columns)
# Out:
# Index(['Region', 'Location', 'Current Using Tech', 'Instant Email Test',
#        '1v1 Video Call Experience', 'Delays in Calls',
#        'Download time for song of 4 times', 'Data Usage in Month',
#        'Usual Phone Usage Purpose', 'Call drop Rate',
#        'Recommendation of network to the tourist', 'Preferred Network',
#        '(VI) Reason of Using Current Network',
#        '(VI) Mobile Bill & WiFi Services Monthly Expense',
#        'Price-Quality Switch(B/W Jio & Airtel)', 'Service Quality Rating (VI)',
#        '(Jio) Reason of Using Current Network',
#        '(Jio) Mobile Bill & WiFi Services Monthly Expense', 'Switch to VI?',
#        'Service Quality Rating (Jio)',
#        '(Airtel) Reason of Using Current Network',
#        '(Airtel) Mobile Bill & WiFi Services Monthly Expense', 'Switch to VI?',
#        'Price-Quality Switch(B/W VI & Airtel)',
#        'Service Quality Rating (Airtel)',
#        'Government Support To Network Companies',
# ...

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['Region', 'Location', 'Current Using Tech', 'Instant Email Test',
#        '1v1 Video Call Experience', 'Delays in Calls',
#        'Download time for song of 4 times', 'Data Usage in Month',
#        'Usual Phone Usage Purpose', 'Call drop Rate',
#        'Recommendation of network to the tourist', 'Preferred Network',
#        '(VI) Reason of Using Current Network',
#        '(VI) Mobile Bill & WiFi Services Monthly Expense',
#        'Price-Quality Switch(B/W Jio & Airtel)', 'Service Quality Rating (VI)',
#        '(Jio) Reason of Using Current Network',
#        '(Jio) Mobile Bill & WiFi Services Monthly Expense', 'Switch to VI?',
#        'Service Quality Rating (Jio)',
#        '(Airtel) Reason of Using Current Network',
#        '(Airtel) Mobile Bill & WiFi Services Monthly Expense', 'Switch to VI?',
#        'Price-Quality Switch(B/W VI & Airtel)',
#        'Service Quality Rating (Airtel)',
#        'Government Support To Network Companies',
# ...

# %%
df.Location.value_counts()
# Out:
# Location
# Urban       36
# Suburban    10
# Rural        4
# Name: count, dtype: int64

# %%
df.Region.value_counts()
# Out:
# Region
# West     23
# North    18
# South     6
# East      3
# Name: count, dtype: int64

# %%
print('Number of responses given to survey/rows in dataframe:', df.shape[0])
print('Number of columns of dataframe',df.shape[1])
# Out:
# Number of responses given to survey/rows in dataframe: 50
# Number of columns of dataframe 27

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df.size
# Out:
# 1350

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 27 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Region                                                             50 non-null     object
#  1   Location                                                           50 non-null     object
#  2   Current Using Tech                                                 50 non-null     object
#  3   Instant Email Test                                                 50 non-null     object
#  4   1v1 Video Call Experience                                          50 non-null     object
#  5   Delays in Calls                                                    50 non-null     object
#  6   Download time for song of 4 times                                  50 non-null     object
# ...

# %%
#finding unique values in each columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 4
#       2 dict={}
#       3 for i in df.columns:
# ----> 4     dict[i]=df[i].value_counts().shape[0]
#       6 pd.DataFrame(dict,index=['Unique']).T.style.background_gradient(cmap='bwr')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:7509, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7506     subset = self.columns.tolist()
#    7508 name = "proportion" if normalize else "count"
# -> 7509 counts = self.groupby(subset, dropna=dropna, observed=False)._grouper.size()
#    7510 counts.name = name
#    7512 if sort:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
# ...
